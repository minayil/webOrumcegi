# %% [markdown]
# <a href="https://colab.research.google.com/github/minayil/webOrumcegi/blob/main/crawler0_0_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup

# %%
urlToplayıcı = input("https başlığı ekleyerek bir url giriniz")
topla = requests.get(urlToplayıcı)
# Out:
# https başlığı ekleyerek bir url girinizhttps://www.hacettepe.edu.tr/

# %%
soup = BeautifulSoup(topla.text, 'html.parser')
for link in soup.find_all("a"):
  print(link.get("href"))
print("Başlıklar: ")
#for title in titles:
 # print(title.text.strip())
# Out:
# /
# https://huysis.hacettepe.edu.tr
# /hakkinda/arama
# https://bidb.hacettepe.edu.tr/tr/e-posta
# https://www.instagram.com/hacettepe_university/
# https://www.facebook.com/HacettepeUniversitesiKurumsal
# https://twitter.com/Hacettepe1967
# https://www.youtube.com/HacettepeKurumsal/
# /kalite
# /ogrenci
# /personel
# https://mezunum.hacettepe.edu.tr/
# https://universitem.hacettepe.edu.tr/
# /hakkinda/iletisim
# https://kalite.hacettepe.edu.tr/tr/geribildirim
# /english
# /ogretim
# /arastirma
# /inovasyon
# /toplumsalkatki
# /saglik
# /uluslararasi
# /yerleskedeyasam
# /hakkinda
# /kalite
# /ogrenci
# /personel
# https://mezunum.hacettepe.edu.tr/
# https://universitem.hacettepe.edu.tr/
# /english
# /
# /hakkinda/iletisim
# /hakkinda/arama
# https://kalite.hacettepe.edu.tr/tr/geribildirim
# https://bidb.hacettepe.edu.tr/tr/e-posta
# https://www.instagram.com/hacettepe_university/
# https://www.facebook.com/HacettepeUniversitesiKurumsal
# https://twitter.com/Hacettepe1967
# ...
